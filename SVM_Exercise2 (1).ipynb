# %% [markdown]
# # Exercise 2

# %% [markdown]
# Using SVM , a company wants to classify emails as spam or not spam based based on features such as word frequenccy ans message length

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
df = pd.read_csv("spam_dataset.csv")
print("Dataset preview:")
print(df.head())
# Out:
# Dataset preview:
#    word_frequency  message_length  label
# 0               5             120      1
# 1               2              45      0
# 2              10             200      1
# 3               1              30      0
# 4               7             150      1

# %%
X = df[["word_frequency", "message_length"]]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = SVC(kernel="rbf", random_state=0)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Not Spam", "Spam"],
            yticklabels=["Not Spam", "Spam"])
plt.title("Confusion Matrix - Spam Classification (SVM)")
plt.show()

# %%
comparison = pd.DataFrame({"Actual": y_test.values, "Predicted": y_pred})
print("\nComparison of Actual vs Predicted:")
print(comparison.head(15))
# Out:
# Comparison of Actual vs Predicted:
#     Actual  Predicted
# 0        0          0
# 1        1          1
# 2        0          0
# 3        1          1
# 4        1          1
# 5        1          1
# 6        0          0
# 7        0          0
# 8        0          0
# 9        1          1
# 10       0          0
# 11       0          0

# %%
plt.scatter(df["word_frequency"], df["message_length"], c=df["label"], cmap="coolwarm", edgecolors="k")
plt.xlabel("Word Frequency")
plt.ylabel("Message Length")
plt.title("Spam vs Not Spam Dataset Distribution")
plt.show()
