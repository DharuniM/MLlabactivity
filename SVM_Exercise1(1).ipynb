# %% [markdown]
# ## Exercise 1 :

# %% [markdown]
# Generate a random dataset and that follows a quadratic distribution using SVM

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
df = pd.read_csv("quadratic_svm.csv")

X = df[["Feature"]]
y = df["Label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = SVC(kernel="rbf")
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Class 0", "Class 1"],
            yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix - SVM (RBF)")
plt.show()

# %%
plt.scatter(df["Feature"], df["Label"], c=df["Label"], cmap="coolwarm", edgecolors="k")
plt.xlabel("Feature")
plt.ylabel("Label")
plt.title("Quadratic Dataset Distribution")
plt.show()

# %%
comparison = pd.DataFrame({"Actual": y_test.values, "Predicted": y_pred})
print(comparison.head(10))
# Out:
#    Actual  Predicted
# 0       0          0
# 1       1          1
# 2       0          0
# 3       0          0
# 4       1          1
# 5       1          1
# 6       1          1
# 7       0          0
# 8       0          0
# 9       0          0
